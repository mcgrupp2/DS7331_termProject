# %%
import datetime
import itertools
import os
import pathlib
import sklearn

import numpy as np
import pandas as pd
import plotly.graph_objects as go
import seaborn as sns
import scipy.stats as stats

from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

# %%
## from: https://www2.1010data.com/documentationcenter/prod/Tutorials/MachineLearningExamples/CensusIncomeDataSet.html
header_names = [
    'age',
    'class_worker',
    'det_ind_code',
    'det_occ_code',
    'education',
    'wage_per_hour',
    'hs_college',
    'marital_stat',
    'major_ind_code',
    'major_occ_code',
    'race',
    'hisp_origin',
    'sex',
    'union_member',
    'unemp_reason',
    'full_or_part_emp',
    'capital_gains',
    'capital_losses',
    'stock_dividends',
    'tax_filer_stat',
    'region_prev_res',
    'state_prev_res',
    'det_hh_fam_stat',
    'det_hh_summ',
    'instance_weight', ## this field is not used as a feature
    'mig_chg_msa',
    'mig_chg_reg',
    'mig_move_reg',
    'mig_same',
    'mig_prev_sunbelt',
    'num_emp',
    'fam_under_18',
    'country_father',
    'country_mother',
    'country_self',
    'citizenship',
    'own_or_self',
    'vet_question',
    'vet_benefits',
    'weeks_worked',
    'year',
    'income_50k',
]

# %%
data_dir = os.path.join(pathlib.Path(os.getcwd()).parent, 'data')
df = pd.read_csv(os.path.join(data_dir, 'census-income.data.csv'), header=None, names=header_names)
df_test = pd.read_csv(os.path.join(data_dir, 'census-income.test.csv'), header=None, names=header_names)
df = pd.concat([df,df_test]) ## the test file is also labelled so they can be merged
df.drop(columns=['instance_weight']) ## not used for our analysis
# Out:
#        age                     class_worker  det_ind_code  det_occ_code  \
# 0       73                  Not in universe             0             0
# 1       58   Self-employed-not incorporated             4            34
# 2       18                  Not in universe             0             0
# 3        9                  Not in universe             0             0
# 4       10                  Not in universe             0             0
# ...    ...                              ...           ...           ...
# 99757   14                  Not in universe             0             0
# 99758   61                          Private             8            36
# 99759   24   Self-employed-not incorporated             1            43
# 99760   30                          Private            45             2
# 99761   67                  Not in universe             0             0
#
#                          education  wage_per_hour        hs_college  \
# 0             High school graduate              0   Not in universe
# 1       Some college but no degree              0   Not in universe
# 2                       10th grade              0       High school
# 3                         Children              0   Not in universe
# 4                         Children              0   Not in universe
# ...                            ...            ...               ...
# 99757                     Children              0   Not in universe
# 99758                   11th grade              0   Not in universe
# 99759            7th and 8th grade              0   Not in universe
# 99760   Bachelors degree(BA AB BS)              0   Not in universe
# 99761                    9th grade              0   Not in universe
#
#                            marital_stat                major_ind_code  \
# 0                               Widowed   Not in universe or children
# 1                              Divorced                  Construction
# 2                         Never married   Not in universe or children
# 3                         Never married   Not in universe or children
# 4                         Never married   Not in universe or children
# ...                                 ...                           ...
# 99757                     Never married   Not in universe or children
# 99758                         Separated   Manufacturing-durable goods
# 99759   Married-civilian spouse present                   Agriculture
# 99760   Married-civilian spouse present   Other professional services
# 99761   Married-civilian spouse present   Not in universe or children
#
#                                major_occ_code  ...  country_father  \
# 0                             Not in universe  ...   United-States
# 1         Precision production craft & repair  ...   United-States
# 2                             Not in universe  ...         Vietnam
# 3                             Not in universe  ...   United-States
# 4                             Not in universe  ...   United-States
# ...                                       ...  ...             ...
# 99757                         Not in universe  ...   United-States
# 99758   Machine operators assmblrs & inspctrs  ...   United-States
# 99759            Farming forestry and fishing  ...          Mexico
# 99760          Executive admin and managerial  ...   United-States
# 99761                         Not in universe  ...   United-States
#
#        country_mother    country_self  \
# 0       United-States   United-States
# 1       United-States   United-States
# 2             Vietnam         Vietnam
# 3       United-States   United-States
# 4       United-States   United-States
# ...               ...             ...
# 99757   United-States   United-States
# 99758   United-States   United-States
# 99759          Mexico          Mexico
# 99760   United-States   United-States
# 99761   United-States   United-States
#
#                                         citizenship own_or_self  \
# 0                 Native- Born in the United States           0
# 1                 Native- Born in the United States           0
# 2               Foreign born- Not a citizen of U S            0
# 3                 Native- Born in the United States           0
# 4                 Native- Born in the United States           0
# ...                                             ...         ...
# 99757             Native- Born in the United States           0
# 99758             Native- Born in the United States           0
# 99759   Foreign born- U S citizen by naturalization           0
# 99760             Native- Born in the United States           0
# 99761             Native- Born in the United States           0
#
#            vet_question  vet_benefits  weeks_worked  year income_50k
# 0       Not in universe             2             0    95   - 50000.
# 1       Not in universe             2            52    94   - 50000.
# 2       Not in universe             2             0    95   - 50000.
# 3       Not in universe             0             0    94   - 50000.
# 4       Not in universe             0             0    94   - 50000.
# ...                 ...           ...           ...   ...        ...
# 99757   Not in universe             0             0    95   - 50000.
# 99758   Not in universe             2            52    95   - 50000.
# 99759   Not in universe             2            52    94   - 50000.
# 99760   Not in universe             2            52    95   - 50000.
# 99761   Not in universe             2             0    94   - 50000.
#
# [299285 rows x 41 columns]

# %%
categorical_features = [
    'class_worker',
    'det_ind_code',
    'det_occ_code',
    'education',
    'hs_college',
    'marital_stat',
    'major_ind_code',
    'major_occ_code',
    'race',
    'hisp_origin',
    'sex',
    'union_member',
    'unemp_reason',
    'full_or_part_emp',
    'tax_filer_stat',
    'region_prev_res',
    'state_prev_res',
    'det_hh_fam_stat',
    'det_hh_summ',
    'mig_chg_msa',
    'mig_chg_reg',
    'mig_move_reg',
    'mig_same',
    'mig_prev_sunbelt',
    'fam_under_18',
    'country_father',
    'country_mother',
    'country_self',
    'citizenship',
    'own_or_self',
    'vet_question',
    'vet_benefits',
    'year',
]
df[categorical_features] = df[categorical_features].astype('category')

# %%
### Drop columns not used in modelling
df = df.drop(
    columns=[
        'state_prev_res',
        'country_father',
        'country_mother',
        'country_self',
    ]
)

# %%
def get_model(classifier, numeric_features, categorical_features):
    ### Scale numerical, one hot categorical
    numeric_transformer = Pipeline(
        steps=[
            #('imputer', SimpleImputer(strategy='median')),
            ('scaler', StandardScaler()),
        ]
    )
    categorical_transformer = Pipeline(
        steps=[
            #('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
            ('onehot', OneHotEncoder(handle_unknown='ignore')),
        ]
    )
    preprocessor = ColumnTransformer(
        transformers=[
            ('num', numeric_transformer, numeric_features),
            ('cat', categorical_transformer, categorical_features)]
    )
    model = Pipeline(
        steps=[
            ('preprocessor', preprocessor),
            ('classifier', classifier),
        ]
    )
    
    return model

# %%
### Find the numerical/ categorical features
target = 'income_50k'
numeric_features = df.select_dtypes(include=['int64', 'float64']).columns
categorical_features = df.select_dtypes(include=['object','bool', 'category']).drop([target], axis=1).columns

X = df.drop(target, axis=1)
y = df[target]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
logreg_param_scores = {}


class_weights =  [None, 'balanced']
penalties = ['none','l1', 'l2',]
solvers = ['lbfgs', 'liblinear']

for cw in class_weights:
    for penalty in penalties:
        for solver in solvers:
            if solver == 'lbfgs' and penalty == 'l1': 
                continue
            if solver == 'liblinear' and penalty == 'none': 
                continue
            params = (cw, penalty, solver)
            print(params)

            classifier = LogisticRegression(class_weight=cw, penalty=penalty, solver=solver, max_iter=100000)
            model = get_model(classifier, numeric_features, categorical_features)
            model.fit(X_train,y_train)
            y_pred = model.predict(X_test)

            acc = accuracy_score(y_pred, y_test)
            logreg_param_scores[params] = acc
            print(acc)

print('=' * 60)
for params, score in logreg_param_scores.items():
    print(params, score)
# Out:
# (None, 'none', 'lbfgs')
# 0.952703944400822
# (None, 'l1', 'liblinear')
# 0.9528208897873265
# (None, 'l2', 'lbfgs')
# 0.9527206508846083
# (None, 'l2', 'liblinear')
# 0.9526705314332492
# ('balanced', 'none', 'lbfgs')
# 0.8562240005346075
# ('balanced', 'l1', 'liblinear')
# 0.8560736421805303
# ('balanced', 'l2', 'lbfgs')
# 0.8562574135021802
# ('balanced', 'l2', 'liblinear')
# 0.8562240005346075
# ============================================================
# (None, 'none', 'lbfgs') 0.952703944400822
# (None, 'l1', 'liblinear') 0.9528208897873265
# (None, 'l2', 'lbfgs') 0.9527206508846083
# (None, 'l2', 'liblinear') 0.9526705314332492
# ('balanced', 'none', 'lbfgs') 0.8562240005346075
# ('balanced', 'l1', 'liblinear') 0.8560736421805303
# ('balanced', 'l2', 'lbfgs') 0.8562574135021802
# ('balanced', 'l2', 'liblinear') 0.8562240005346075

# %%
best_logistic_regression = LogisticRegression(class_weight=None, penalty='l1', solver='liblinear', max_iter=100000)
best_logistic_regression_model = get_model(best_logistic_regression, numeric_features, categorical_features)
best_logistic_regression_model.fit(X_train,y_train)
best_logistic_regression_coefs = best_logistic_regression_model.named_steps['classifier'].coef_

# %%
## get catergorical cols after one hot
cat_columns = best_logistic_regression_model.named_steps['preprocessor'].transformers_[1][1]\
    .named_steps['onehot'].get_feature_names(categorical_features)
## combine numerical and categorical (same order as pipeline)
all_cols = np.concatenate((numeric_features, cat_columns), axis=0)
coef_scores = [coef_score for coef_score in zip(all_cols,best_logistic_regression_coefs[0])]
coef_scores.sort(key=lambda tup: abs(tup[1]), reverse=True)
for coef, weight in coef_scores:
    print('{coef:70}{weight:.3f}'.format(coef=coef, weight=weight))
# Out:
# education_ Doctorate degree(PhD EdD)                                  2.025
# tax_filer_stat_ Nonfiler                                              -1.844
# education_ Prof school degree (MD DDS DVM LLB JD)                     1.721
# sex_ Female                                                           -1.543
# education_ Masters degree(MA MS MEng MEd MSW MBA)                     1.516
# education_ Children                                                   -1.510
# education_ Less than 1st grade                                        -1.403
# det_ind_code_26                                                       1.271
# det_hh_summ_ Child under 18 never married                             -1.253
# det_hh_fam_stat_ Spouse of RP of unrelated subfamily                  1.243
# det_occ_code_7                                                        1.143
# det_occ_code_21                                                       1.106
# major_occ_code_ Private household services                            -1.084
# det_ind_code_20                                                       1.045
# education_ 10th grade                                                 -0.966
# weeks_worked                                                          0.931
# full_or_part_emp_ Children or Armed Forces                            -0.928
# education_ Bachelors degree(BA AB BS)                                 0.912
# det_occ_code_11                                                       0.911
# class_worker_ Without pay                                             -0.881
# major_occ_code_ Adm support including clerical                        -0.871
# det_hh_summ_ Child 18 or older                                        -0.869
# det_ind_code_13                                                       0.864
# education_ 7th and 8th grade                                          -0.809
# education_ 5th or 6th grade                                           -0.799
# major_ind_code_ Social services                                       -0.788
# det_occ_code_44                                                       -0.787
# education_ 9th grade                                                  -0.761
# age                                                                   0.757
# mig_prev_sunbelt_ ?                                                   -0.755
# det_ind_code_25                                                       0.749
# det_ind_code_3                                                        0.745
# det_occ_code_42                                                       -0.737
# det_occ_code_2                                                        0.685
# hisp_origin_ Do not know                                              -0.683
# major_occ_code_ Other service                                         -0.676
# unemp_reason_ New entrant                                             0.653
# class_worker_ State government                                        -0.651
# det_ind_code_6                                                        -0.634
# major_occ_code_ Machine operators assmblrs & inspctrs                 -0.626
# hs_college_ College or university                                     -0.611
# class_worker_ Self-employed-incorporated                              0.605
# det_occ_code_31                                                       -0.597
# education_ 11th grade                                                 -0.579
# det_hh_fam_stat_ Child 18+ spouse of subfamily RP                     -0.571
# det_occ_code_41                                                       -0.567
# education_ 1st 2nd 3rd or 4th grade                                   -0.564
# region_prev_res_ Midwest                                              -0.551
# marital_stat_ Married-A F spouse present                              -0.543
# class_worker_ Never worked                                            0.541
# major_ind_code_ Utilities and sanitary services                       0.534
# det_occ_code_8                                                        0.526
# det_occ_code_12                                                       -0.513
# det_hh_fam_stat_ In group quarters                                    -0.493
# hisp_origin_ Central or South American                                -0.488
# education_ 12th grade no diploma                                      -0.488
# full_or_part_emp_ Unemployed part- time                               -0.486
# capital_gains                                                         0.485
# det_occ_code_19                                                       -0.484
# det_occ_code_15                                                       0.483
# det_occ_code_5                                                        0.480
# det_ind_code_39                                                       -0.479
# major_occ_code_ Handlers equip cleaners etc                           -0.471
# citizenship_ Native- Born in Puerto Rico or U S Outlying              -0.463
# det_occ_code_27                                                       -0.460
# det_hh_summ_ Other relative of householder                            -0.450
# sex_ Male                                                             -0.447
# det_ind_code_33                                                       -0.444
# det_occ_code_29                                                       -0.442
# det_occ_code_4                                                        0.434
# det_occ_code_10                                                       -0.434
# det_occ_code_20                                                       -0.427
# major_occ_code_ Professional specialty                                0.426
# det_ind_code_5                                                        -0.423
# major_occ_code_ Sales                                                 0.419
# det_occ_code_22                                                       0.406
# tax_filer_stat_ Single                                                -0.402
# num_emp                                                               0.401
# det_ind_code_19                                                       -0.400
# det_ind_code_23                                                       0.397
# tax_filer_stat_ Joint both 65+                                        -0.396
# det_hh_fam_stat_ RP of unrelated subfamily                            -0.391
# major_ind_code_ Education                                             -0.387
# tax_filer_stat_ Joint one under 65 & one 65+                          -0.385
# major_occ_code_ Executive admin and managerial                        0.375
# hisp_origin_ Mexican (Mexicano)                                       -0.371
# unemp_reason_ Re-entrant                                              -0.371
# det_ind_code_8                                                        0.370
# det_hh_fam_stat_ Child 18+ ever marr Not in a subfamily               0.367
# det_occ_code_16                                                       0.357
# det_occ_code_18                                                       0.354
# det_ind_code_41                                                       -0.350
# major_ind_code_ Medical except hospital                               -0.343
# class_worker_ Local government                                        -0.339
# stock_dividends                                                       0.337
# marital_stat_ Never married                                           -0.333
# det_occ_code_45                                                       0.333
# mig_prev_sunbelt_ Yes                                                 -0.329
# det_ind_code_47                                                       0.329
# det_hh_fam_stat_ Child 18+ ever marr RP of subfamily                  0.324
# mig_move_reg_ ?                                                       -0.322
# union_member_ No                                                      -0.311
# mig_chg_msa_ MSA to MSA                                               0.311
# det_ind_code_22                                                       -0.308
# det_ind_code_30                                                       0.301
# vet_benefits_2                                                        -0.298
# det_ind_code_18                                                       -0.296
# own_or_self_2                                                         -0.295
# union_member_ Not in universe                                         -0.292
# marital_stat_ Married-civilian spouse present                         -0.283
# education_ Associates degree-academic program                         0.282
# mig_same_ No                                                          -0.282
# det_occ_code_38                                                       -0.270
# own_or_self_0                                                         -0.264
# vet_question_ Not in universe                                         -0.249
# race_ Black                                                           -0.249
# hisp_origin_ Other Spanish                                            -0.245
# det_ind_code_48                                                       -0.244
# unemp_reason_ Job leaver                                              -0.243
# race_ Amer Indian Aleut or Eskimo                                     -0.239
# mig_chg_msa_ NonMSA to nonMSA                                         -0.238
# year_94                                                               -0.237
# det_ind_code_11                                                       0.228
# own_or_self_1                                                         0.224
# det_occ_code_32                                                       0.223
# det_ind_code_38                                                       -0.221
# mig_chg_msa_ MSA to nonMSA                                            -0.221
# det_occ_code_17                                                       0.212
# hisp_origin_ Mexican-American                                         -0.209
# det_ind_code_44                                                       -0.205
# det_ind_code_51                                                       0.205
# det_hh_fam_stat_ Other Rel 18+ ever marr not in subfamily             -0.204
# vet_question_ Yes                                                     -0.201
# det_occ_code_37                                                       -0.200
# det_ind_code_12                                                       0.185
# education_ High school graduate                                       -0.180
# det_ind_code_15                                                       0.173
# det_hh_summ_ Nonrelative of householder                               -0.169
# major_ind_code_ Agriculture                                           -0.169
# education_ Associates degree-occup /vocational                        0.164
# full_or_part_emp_ Unemployed full-time                                -0.164
# region_prev_res_ West                                                 0.163
# det_occ_code_14                                                       -0.163
# det_ind_code_34                                                       0.162
# det_ind_code_14                                                       0.162
# major_ind_code_ Communications                                        0.161
# capital_losses                                                        0.154
# det_hh_fam_stat_ Nonfamily householder                                0.153
# mig_move_reg_ Same county                                             -0.153
# det_occ_code_24                                                       -0.146
# det_ind_code_21                                                       -0.145
# det_hh_fam_stat_ Child 18+ never marr Not in a subfamily              -0.142
# region_prev_res_ Not in universe                                      -0.136
# det_occ_code_6                                                        -0.135
# major_ind_code_ Transportation                                        0.132
# det_occ_code_28                                                       0.129
# major_occ_code_ Armed Forces                                          0.129
# tax_filer_stat_ Joint both under 65                                   0.129
# education_ Some college but no degree                                 0.126
# mig_move_reg_ Different state in Midwest                              -0.124
# det_occ_code_26                                                       -0.124
# major_ind_code_ Retail trade                                          -0.122
# race_ Asian or Pacific Islander                                       -0.121
# major_occ_code_ Protective services                                   0.118
# fam_under_18_ Not in universe                                         -0.118
# det_occ_code_35                                                       -0.114
# det_hh_fam_stat_ Other Rel 18+ ever marr RP of subfamily              0.105
# citizenship_ Native- Born in the United States                        -0.105
# mig_chg_reg_ Different region                                         0.101
# citizenship_ Foreign born- Not a citizen of U S                       -0.100
# mig_chg_reg_ Different division same region                           0.099
# major_ind_code_ Manufacturing-durable goods                           0.099
# marital_stat_ Separated                                               -0.096
# major_ind_code_ Public administration                                 0.096
# unemp_reason_ Not in universe                                         -0.093
# mig_chg_reg_ Different state same division                            -0.092
# det_occ_code_40                                                       0.092
# class_worker_ Private                                                 -0.092
# det_ind_code_37                                                       0.091
# major_occ_code_ Transportation and material moving                    -0.090
# det_ind_code_7                                                        -0.087
# det_ind_code_16                                                       0.087
# full_or_part_emp_ Not in labor force                                  0.084
# det_hh_fam_stat_ Other Rel 18+ spouse of subfamily RP                 0.083
# class_worker_ Federal government                                      0.081
# full_or_part_emp_ PT for econ reasons usually PT                      -0.081
# det_ind_code_29                                                       0.079
# hs_college_ Not in universe                                           -0.078
# hisp_origin_ Chicano                                                  -0.072
# det_occ_code_33                                                       -0.069
# major_ind_code_ Forestry and fisheries                                -0.069
# det_ind_code_40                                                       -0.069
# citizenship_ Native- Born abroad of American Parent(s)                -0.068
# det_occ_code_46                                                       0.065
# mig_move_reg_ Abroad                                                  -0.063
# det_ind_code_1                                                        -0.060
# det_ind_code_46                                                       -0.060
# hisp_origin_ NA                                                       0.057
# major_ind_code_ Finance insurance and real estate                     0.056
# major_ind_code_ Entertainment                                         -0.048
# mig_move_reg_ Different state in South                                0.048
# det_occ_code_25                                                       -0.046
# region_prev_res_ South                                                -0.045
# hisp_origin_ All other                                                0.044
# marital_stat_ Divorced                                                -0.039
# class_worker_ Self-employed-not incorporated                          -0.038
# det_ind_code_28                                                       -0.036
# det_ind_code_17                                                       -0.036
# det_occ_code_1                                                        -0.033
# instance_weight                                                       0.029
# full_or_part_emp_ Full-time schedules                                 0.025
# hisp_origin_ Puerto Rican                                             0.024
# det_hh_fam_stat_ Spouse of householder                                0.024
# major_ind_code_ Other professional services                           0.020
# det_ind_code_32                                                       -0.019
# det_occ_code_34                                                       0.018
# citizenship_ Foreign born- U S citizen by naturalization              0.017
# mig_move_reg_ Different state in West                                 0.016
# wage_per_hour                                                         -0.016
# major_ind_code_ Personal services except private HH                   -0.012
# race_ White                                                           0.012
# major_ind_code_ Wholesale trade                                       -0.011
# major_ind_code_ Mining                                                0.011
# det_occ_code_3                                                        0.010
# major_ind_code_ Armed Forces                                          0.008
# marital_stat_ Married-spouse absent                                   0.008
# det_ind_code_45                                                       0.007
# det_ind_code_49                                                       0.007
# major_occ_code_ Precision production craft & repair                   -0.005
# det_ind_code_4                                                        -0.003
# mig_same_ Not in universe under 1 year old                            -0.002
# mig_chg_reg_ ?                                                        -0.002
# det_ind_code_42                                                       -0.001
# det_hh_summ_ Householder                                              0.001
# year_95                                                               -0.000
# det_ind_code_43                                                       -0.000
# det_ind_code_31                                                       0.000
# class_worker_ Not in universe                                         0.000
# det_ind_code_0                                                        0.000
# det_ind_code_2                                                        0.000
# det_ind_code_9                                                        0.000
# det_ind_code_10                                                       0.000
# det_ind_code_24                                                       0.000
# det_ind_code_27                                                       0.000
# det_ind_code_35                                                       0.000
# det_ind_code_36                                                       0.000
# det_ind_code_50                                                       0.000
# det_occ_code_0                                                        0.000
# det_occ_code_9                                                        0.000
# det_occ_code_13                                                       0.000
# det_occ_code_23                                                       0.000
# det_occ_code_30                                                       0.000
# det_occ_code_36                                                       0.000
# det_occ_code_39                                                       0.000
# det_occ_code_43                                                       0.000
# hs_college_ High school                                               0.000
# marital_stat_ Widowed                                                 0.000
# major_ind_code_ Business and repair services                          0.000
# major_ind_code_ Construction                                          0.000
# major_ind_code_ Hospital services                                     0.000
# major_ind_code_ Manufacturing-nondurable goods                        0.000
# major_ind_code_ Not in universe or children                           0.000
# major_ind_code_ Private household services                            0.000
# major_occ_code_ Farming forestry and fishing                          0.000
# major_occ_code_ Not in universe                                       0.000
# major_occ_code_ Technicians and related support                       0.000
# race_ Other                                                           0.000
# hisp_origin_ Cuban                                                    0.000
# union_member_ Yes                                                     0.000
# unemp_reason_ Job loser - on layoff                                   0.000
# unemp_reason_ Other job loser                                         0.000
# full_or_part_emp_ PT for econ reasons usually FT                      0.000
# full_or_part_emp_ PT for non-econ reasons usually FT                  0.000
# tax_filer_stat_ Head of household                                     0.000
# region_prev_res_ Abroad                                               0.000
# region_prev_res_ Northeast                                            0.000
# det_hh_fam_stat_ Child 18+ never marr RP of subfamily                 0.000
# det_hh_fam_stat_ Child <18 ever marr RP of subfamily                  0.000
# det_hh_fam_stat_ Child <18 ever marr not in subfamily                 0.000
# det_hh_fam_stat_ Child <18 never marr RP of subfamily                 0.000
# det_hh_fam_stat_ Child <18 never marr not in subfamily                0.000
# det_hh_fam_stat_ Child <18 spouse of subfamily RP                     0.000
# det_hh_fam_stat_ Child under 18 of RP of unrel subfamily              0.000
# det_hh_fam_stat_ Grandchild 18+ ever marr RP of subfamily             0.000
# det_hh_fam_stat_ Grandchild 18+ ever marr not in subfamily            0.000
# det_hh_fam_stat_ Grandchild 18+ never marr RP of subfamily            0.000
# det_hh_fam_stat_ Grandchild 18+ never marr not in subfamily           0.000
# det_hh_fam_stat_ Grandchild 18+ spouse of subfamily RP                0.000
# det_hh_fam_stat_ Grandchild <18 ever marr not in subfamily            0.000
# det_hh_fam_stat_ Grandchild <18 never marr RP of subfamily            0.000
# det_hh_fam_stat_ Grandchild <18 never marr child of subfamily RP      0.000
# det_hh_fam_stat_ Grandchild <18 never marr not in subfamily           0.000
# det_hh_fam_stat_ Householder                                          0.000
# det_hh_fam_stat_ Other Rel 18+ never marr RP of subfamily             0.000
# det_hh_fam_stat_ Other Rel 18+ never marr not in subfamily            0.000
# det_hh_fam_stat_ Other Rel <18 ever marr RP of subfamily              0.000
# det_hh_fam_stat_ Other Rel <18 ever marr not in subfamily             0.000
# det_hh_fam_stat_ Other Rel <18 never marr child of subfamily RP       0.000
# det_hh_fam_stat_ Other Rel <18 never marr not in subfamily            0.000
# det_hh_fam_stat_ Other Rel <18 never married RP of subfamily          0.000
# det_hh_fam_stat_ Other Rel <18 spouse of subfamily RP                 0.000
# det_hh_fam_stat_ Secondary individual                                 0.000
# det_hh_summ_ Child under 18 ever married                              0.000
# det_hh_summ_ Group Quarters- Secondary individual                     0.000
# det_hh_summ_ Spouse of householder                                    0.000
# mig_chg_msa_ ?                                                        0.000
# mig_chg_msa_ Abroad to MSA                                            0.000
# mig_chg_msa_ Abroad to nonMSA                                         0.000
# mig_chg_msa_ NonMSA to MSA                                            0.000
# mig_chg_msa_ Nonmover                                                 0.000
# mig_chg_msa_ Not identifiable                                         0.000
# mig_chg_msa_ Not in universe                                          0.000
# mig_chg_reg_ Abroad                                                   0.000
# mig_chg_reg_ Different county same state                              0.000
# mig_chg_reg_ Nonmover                                                 0.000
# mig_chg_reg_ Not in universe                                          0.000
# mig_chg_reg_ Same county                                              0.000
# mig_move_reg_ Different county same state                             0.000
# mig_move_reg_ Different state in Northeast                            0.000
# mig_move_reg_ Nonmover                                                0.000
# mig_move_reg_ Not in universe                                         0.000
# mig_same_ Yes                                                         0.000
# mig_prev_sunbelt_ No                                                  0.000
# mig_prev_sunbelt_ Not in universe                                     0.000
# fam_under_18_ Both parents present                                    0.000
# fam_under_18_ Father only present                                     0.000
# fam_under_18_ Mother only present                                     0.000
# fam_under_18_ Neither parent present                                  0.000
# vet_question_ No                                                      0.000
# vet_benefits_0                                                        0.000
# vet_benefits_1                                                        0.000

# %%
sgd_param_scores = {}


class_weights =  [None, 'balanced']
penalties = ['l1', 'l2']
alphas = [0.00001, 0.0001, 0.001, 0.01, 0.1]

for cw in class_weights:
    for penalty in penalties:
        for alpha in alphas:
            params = (cw, penalty, alpha)
            print(params)

            classifier = SGDClassifier(class_weight=cw, penalty=penalty, alpha=alpha, max_iter=100000)
            model = get_model(classifier, numeric_features, categorical_features)
            model.fit(X_train,y_train)
            y_pred = model.predict(X_test)

            acc = accuracy_score(y_pred, y_test)
            sgd_param_scores[params] = acc
            print(acc)

print('=' * 60)
for params, score in sgd_param_scores.items():
    print(params, score)
# Out:
# (None, 'l1', 1e-05)
# 0.9512671867951952
# (None, 'l1', 0.0001)
# 0.9494795930300549
# (None, 'l1', 0.001)
# 0.9441001052508479
# (None, 'l1', 0.01)
# 0.939572648144745
# (None, 'l1', 0.1)
# 0.9381860099904773
# (None, 'l2', 1e-05)
# 0.9498805486409275
# (None, 'l2', 0.0001)
# 0.9512170673438362
# (None, 'l2', 0.001)
# 0.9483268456487963
# (None, 'l2', 0.01)
# 0.9428972384182301
# (None, 'l2', 0.1)
# 0.940040429690763
# ('balanced', 'l1', 1e-05)
# 0.8354077217368061
# ('balanced', 'l1', 0.0001)
# 0.849658352406569
# ('balanced', 'l1', 0.001)
# 0.8340544965501111
# ('balanced', 'l1', 0.01)
# 0.7937250446898442
# ('balanced', 'l1', 0.1)
# 0.6116076649347612
# ('balanced', 'l2', 1e-05)
# 0.8380640526588369
# ('balanced', 'l2', 0.0001)
# 0.8168468182501629
# ('balanced', 'l2', 0.001)
# 0.8576607581402342
# ('balanced', 'l2', 0.01)
# 0.8126200778522145
# ('balanced', 'l2', 0.1)
# 0.7769851479359139
# ============================================================
# (None, 'l1', 1e-05) 0.9512671867951952
# (None, 'l1', 0.0001) 0.9494795930300549
# (None, 'l1', 0.001) 0.9441001052508479
# (None, 'l1', 0.01) 0.939572648144745
# (None, 'l1', 0.1) 0.9381860099904773
# (None, 'l2', 1e-05) 0.9498805486409275
# (None, 'l2', 0.0001) 0.9512170673438362
# (None, 'l2', 0.001) 0.9483268456487963
# (None, 'l2', 0.01) 0.9428972384182301
# (None, 'l2', 0.1) 0.940040429690763
# ('balanced', 'l1', 1e-05) 0.8354077217368061
# ('balanced', 'l1', 0.0001) 0.849658352406569
# ('balanced', 'l1', 0.001) 0.8340544965501111
# ('balanced', 'l1', 0.01) 0.7937250446898442
# ('balanced', 'l1', 0.1) 0.6116076649347612
# ('balanced', 'l2', 1e-05) 0.8380640526588369
# ('balanced', 'l2', 0.0001) 0.8168468182501629
# ('balanced', 'l2', 0.001) 0.8576607581402342
# ('balanced', 'l2', 0.01) 0.8126200778522145
# ('balanced', 'l2', 0.1) 0.7769851479359139
